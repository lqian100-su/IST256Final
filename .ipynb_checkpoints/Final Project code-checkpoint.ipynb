# %%
"IST256 Final Project"
"Group 22"
"Group Member: Eden Tafesse, Jiaqiao Wang, Liuqi Qian"

# %%
#Jiaqiao Wang, create dictionary of currency type and exchange rate.
currencytype=["0","XAF","ARS","AUD","BSD","BRL","BGN","CAD","CLP","CNY","COP","HRK","CYP","CZK","DKK","LTC","BTC","XCD","EEK","EUR","FJD","XPF","GHS","GTQ","HNL","HKD","HUF","ISK","INR","IDR","ILS","JMD","JPY","LVL","LTL","MYR","MXN","MAD","MMK","ANG","NZD","NOK","PKR","PAB","PEN","PHP","PLN","GOLD","QAR","RON","RUB","SAR","RSD","SGD","ZAR","KRW","LKR","SEK","CHF","TWD","THB","TTD","TND","TRY","AED","GBP","USD","VND","VEF"]
exchangerate=[0,582.43,14.32,1.30,1.0,3.74,1.73,1.2835,663.85,6.4825,2991.92,6.6401,0.519911,23.987,6.6060,0.3112,0.002376,2.6898,11.73,0.88,2.0501,105.90,3.8245,7.8792,22.550,7.7564,276.56,124.49,66.573,13232.29,3.7828,121.78,109.14,0.62,3.05,3.91,17.42,9.70,1178.2,1.79,1.45,8.24,104.67,1.0,3.27,46.14,3.82,0.000813,3.64,3.97,66.07,3.75,109.14,1.36,14.56,1151.75,146.25,8.14,0.97,32.41,35.11,6.60,2.02,2.85,3.67,0.71,1.0,22309.50,9.95,]

currencyDict = dict()
for i in range(0,len(currencytype)):
    
    currencyDict[currencytype[i]]=exchangerate[i]

    
def usdToCurrency(amount,currency):
    return amount*currency

# import all necessary tools for using APIs, retrieving URL, and creating dataframes. and miscellaneous functions.
import requests
import json
import pandas as pd
import os
from collections import defaultdict
from datetime import datetime
import urllib.request
import urllib.parse
from zipfile  import ZipFile
import pytz 
from pprint import pprint

## country description, Liuqi Qian.
url = 'https://restcountries.eu/rest/v2/all'
response = requests.get(url)
##response.ok ##the request works
##response.text ##what's in the body of the response
country = response.json()
country_df = pd.DataFrame(country)
##country_df ##show the dataframe of the url
country_name = country_df['name']
country_name = country_name.tolist()
##print(country_name)
country_area = country_df['area']
country_area = country_area.tolist()
##print(country_area)
country_capital = country_df['capital']
country_capital = country_capital.tolist()
##print(country_capital)
country_region = country_df['region']
country_region = country_region.tolist()
##print(country_region)
country_currencies = country_df['currencies']
country_currencies = country_currencies.tolist()
##print(country_currencies)
country_population = country_df['population']
country_population = country_population.tolist()
##print(country_population)
country_language = country_df['languages']
country_language = country_language.tolist()
name = input("Enter the country you want to visit: (e.g. United States of America)")
try:
    if name in country_name:
        number = country_name.index(name)
        ##print(number)
        area = country_area[number]
        ##print(area)
        capital = country_capital[number]
        ##print(capital)
        region = country_region[number]
        ##print(region)
        population = country_area[number]
        ##print(population)
        currencies_code = country_currencies[number][0]['code']
        ##print(currencies_code)
        currencies_name = country_currencies[number][0]['name']
        ##print(currencies_name)
        currencies_symbol = country_currencies[number][0]['symbol']
        ##print(currencies_symbol)
        language_name = country_language[number][0]['name']
        ##print(language_name)
        print("")
        print("%s is the country which is in the %s." %(name,region))
        print("It has about %0.0f people there." %(population))
        print("The country covers an area about %0.0f square kilometers " %(area))
        print("The capital of the country is %s." %(capital))
        print("The language they use is %s." %(language_name))
        print("It uses the %s (%s,'%s') as local currency." %(currencies_name,currencies_code,currencies_symbol))
        print("")
        currency = input("Do you want to exchange the money? (Y / N)")
        ## currency exchange, optional. Eden Tafesse.
        try:
            if currency == "Y":
                amount = eval(input("How much USD would you like to convert? "))
                currency = currencies_code
                result = usdToCurrency(amount,currencyDict[currency])
                print("%s USD represents %.2f in %s" % (str(amount), result, currency))
                
            elif currency == "N":
                print("quiting...")
                quit
            else:
                print("Input not recognized.")
        except ValueError:
            print("Wrong type of input.")
    else:
        print("")
        print('Please enter a correct country name!')
except:
    print("Currency type is not available, we are extremely sorry.")

print("")
print("NOW THE CITIES")
print("---------------")
##city = input("Enter the city you are going to: ")
## time zones. Jiaqiao Wang.
url = 'http://download.geonames.org/export/dump/'
basename = 'cities15000' 
filename = basename + '.zip'

# get the file using urllib
if not os.path.exists(filename):
    urllib.request.urlretrieve(urllib.request.urljoin(url, filename), filename)

# parse the file to do timezone finding
timezones = defaultdict(set)
with ZipFile(filename) as zf, zf.open(basename + '.txt') as file:
    for line in file:
        values = line.split(b'\t')
        if values: 
            name, asciiname, alternatenames = values[1:4]
            timezone = values[-2].decode('utf-8').strip()
            if timezone:
                for city in [name, asciiname] + alternatenames.split(b','):
                    city = city.decode('utf-8').strip()
                    if city:
                        timezones[city].add(timezone)



# input and output
formats = '%Y-%m-%d %H:%M:%S %Z%z'
city = input("Enter any city: (Not restricted to the country above) ")
try:
    for tzname in timezones[city]:
        now = datetime.now(pytz.timezone(tzname))
        print("")
        print("%s is in %s timezone" % (city, tzname))
        print("Current time in %s is %s" % (city, now.strftime(formats)))
# resturant finder, Jiaqiao Wang.  
# get the API and set up the variables.
    url = "https://developers.zomato.com/api/v2.1/cities?q=" + city
    header = {"User-agent": "curl/7.43.0", "Accept": "application/json", "user_key": "18be42a2ada2f9e0fa409457579a66a0"}

    response = requests.get(url, headers=header)
    data = response.json()
    city_id = str(data['location_suggestions'][0]['id'])

    url2 = ("https://developers.zomato.com/api/v2.1/location_details?entity_id= %s&entity_type=city" % (city_id))
    header = {"User-agent": "curl/7.43.0", "Accept": "application/json", "user_key": "18be42a2ada2f9e0fa409457579a66a0"}
    response2 = requests.get(url2, headers=header)
    best = response2.json()
    ## print statement
    print("---------------")
    print("The Top 1 resturant in the city is",best['best_rated_restaurant'][0]['restaurant']['name'])
    print("It's a",best['best_rated_restaurant'][0]['restaurant']['cuisines'],"restaurant")
    print("The average cost for two people is",best['best_rated_restaurant'][0]['restaurant']['average_cost_for_two'])
    print("The rating of this restaurant is",best['best_rated_restaurant'][0]['restaurant']['user_rating']['aggregate_rating'],"out of 5")
    print("")
    print("The Top 2 resturant in the city is",best['best_rated_restaurant'][1]['restaurant']['name'])
    print("It's a",best['best_rated_restaurant'][1]['restaurant']['cuisines'],"restaurant")
    print("The average cost for two people is",best['best_rated_restaurant'][1]['restaurant']['average_cost_for_two'])
    print("The rating of this restaurant is",best['best_rated_restaurant'][1]['restaurant']['user_rating']['aggregate_rating'],"out of 5")
    print("")
    print("The Top 3 resturant in the city is",best['best_rated_restaurant'][2]['restaurant']['name'])
    print("It's a",best['best_rated_restaurant'][2]['restaurant']['cuisines'],"restaurant")
    print("The average cost for two people is",best['best_rated_restaurant'][2]['restaurant']['average_cost_for_two'])
    print("The rating of this restaurant is",best['best_rated_restaurant'][2]['restaurant']['user_rating']['aggregate_rating'],"out of 5")

except IndexError:
    print("Sorry. We don't offer the resturant finding service for this city. ")
## Weather finder, Eden Tafesse.
#get API
api_address = 'http://api.openweathermap.org/data/2.5/weather?appid=6813a6983f74d1717553e1cf356ea175&q='
api = api_address + city

json_data = requests.get(api).json()
http_status_code = json_data['cod']
# main code.
if http_status_code == 200:
    formatted_data_k = float(json_data['main']['temp'])
    formatted_data_f = (formatted_data_k - 273.15) * 1.8 + 32
    print("---------------")
    print("The temperate of %s now is %0.2f ℉" %(city,formatted_data_f))

else:
    print('Weather for the city not found or Something went wrong')
# Out:
# Enter the country you want to visit: (e.g. United States of America)United States of America
#
# United States of America is the country which is in the Americas.
# It has about 9629091 people there.
# The country covers an area about 9629091 square kilometers
# The capital of the country is Washington, D.C..
# The language they use is English.
# It uses the United States dollar (USD,'$') as local currency.
#
# Do you want to exchange the money? (Y / N)Y
# How much USD would you like to convert? 150
# 150 USD represents 150.00 in USD
#
# NOW THE CITIES
# ---------------
# Enter any city: (Not restricted to the country above) Syracuse
#
# Syracuse is in America/Denver timezone
# Current time in Syracuse is 2017-12-11 07:28:38 MST-0700
#
# Syracuse is in Europe/Rome timezone
# Current time in Syracuse is 2017-12-11 15:28:38 CET+0100
#
# Syracuse is in America/New_York timezone
# Current time in Syracuse is 2017-12-11 09:28:38 EST-0500
# ---------------
# The Top 1 resturant in the city is Dinosaur BBQ
# It's a American, BBQ, Southern restaurant
# The average cost for two people is 25
# The rating of this restaurant is 4.9 out of 5
#
# The Top 2 resturant in the city is Pastabilities
# It's a International, Italian restaurant
# The average cost for two people is 25
# The rating of this restaurant is 4.7 out of 5
#
# The Top 3 resturant in the city is Alto Cinco
# It's a Mexican, Tex-Mex, Vegetarian restaurant
# The average cost for two people is 25
# The rating of this restaurant is 4.6 out of 5
# ---------------
# The temperate of Syracuse now is 25.74 ℉
